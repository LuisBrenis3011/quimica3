# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisBrenis3011/quimica3/blob/main/pc1MoralesBrenis_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pregunta 1: Sobre el ABC de python (4 puntos)
# Durante la semana de revisión del material "ABC de python", reflexiona sobre qué conceptos aprendiste con claridad y cuáles consideras los más desafiantes. A continuación resuelve los siguiente ejercicios, puedes ayudarte del material en http://bit.ly/3YKICSZ.

# %%
# Imprime la versión de python que usas y las palabras reservadas de python para esa versión.
import sys, keyword
a= sys.version
b= keyword.kwlist
print(f"Versión de Python: {a}")

print(f"Palabras reservadas de Python: {b}")

# %%
# Crea una matriz de 3x3 e imprime la suma de los elementos en su diagonal (traza).
matriz=[]
for i in range(3):
    fila=[]
    for j in range (3):
        num=int(input(f"ingrese el numero de la fila {i+1}, columna {j+1}: "))
        fila.append(num)
    matriz.append(fila)

for fila in matriz:
    print(fila)

suma_diagonal=0

for i in range(3):
    suma_diagonal+=matriz[i-1][j-1]

print(f"la suma de los numeros de la diagonal en la matriz es: {suma_diagonal}")

# %%
# Guarda como variable la masa atómica de los elementos C, H y O, e imprime la masa molecular del etanol.
masa_carbono = int(12)
masa_hidrogeno = int(1)
masa_oxigeno = int(16)

masa_molecular_etanol = (2 * masa_carbono) + (6 * masa_hidrogeno) + masa_oxigeno

print("Masa molecular del etanol (C2H6O):", masa_molecular_etanol)

# %%
# Busca la temperatura de fusión en Celsius de 5 metales y guárdalos en una lista. Imprime las temperaturas en Kelvin
temperaturas_celsius = {
    "Hierro": 1538,
    "Cobre": 1085,
    "Plata": 961.8,
    "Oro": 1064,
    "Aluminio": 660.3
}
# para convertir a Kelvin se debe sumar +273
temperaturas_kelvin = {metal: temp_celsius + 273 for metal, temp_celsius in temperaturas_celsius.items()}

for metal, temp_kelvin in temperaturas_kelvin.items():
    print(f"Temperatura de fusión de {metal}: {temp_kelvin} K")

# %% [markdown]
# Pregunta 2: Operaciones (4 puntos)
# Escribe un programa que lea repetidamente elementos químicos en español hasta que el usuario introduzca “fin”. Una vez se haya introducido “fin”, muestra por pantalla (o sea imprime) el total de elementos ingresados. Si el usuario introduce cualquier otra cosa que no sea un elemento químico, detecta su fallo usando try y except, muestra un mensaje de error y pasa al siguiente elemento.

# %%
# !pip install periodictable
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 752.5/752.5 kB 16.2 MB/s eta 0:00:00
# ...

# %%
#profesor, para este ejercicio tuve que adquirir la librería "periodictable" que detecta los simbolos quimicos, no sus nombres en español.
# !pip install periodictable
import periodictable
elementos_quimicos = set()
terminar = False

while not terminar:
    elemento = input("ingresar simbolo químico, puedes escribir (fin): ")
    if elemento.lower() == "fin":
        terminar = True
    else:
        try:
            if periodictable.formula(elemento):
                elementos_quimicos.add(elemento)
            else:
                print(f"Error: '{elemento}' no es un elemento químico válido.")
        except:
            print(f"Error: '{elemento}' no es un elemento químico válido.")

elementos_validos = len(elementos_quimicos)
print(f"Total de elementos ingresados: {elementos_validos}")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pregunta 3: Conservación de la masa (4 puntos)

# %%
# !pip install faerun-notebook==0.1.5b0

import ipywidgets as widgets
from faerun_notebook import SmilesDrawer
from google.colab import output
output.enable_custom_widget_manager()

# %%
SmilesDrawer(value=[("Rxn", "C(C1C(C(C(C(O1)O)O)O)O)O.O=O>>C(=O)=O.O")], theme='dark', background="#1e1e1e", options={'scale': 1.25})

# %%
# !pip install chempy
from chempy import balance_stoichiometry
reactantes = {'C6H12O6': 1, 'O2': 1}
productos = {'CO2': 1, 'H2O': 1}
balanceo = balance_stoichiometry(reactantes, productos)
reactante_equilibrado = " + ".join([f"{coeficiente} {elemento}" for elemento, coeficiente in balanceo[0].items()])
producto_equilibrado = " + ".join([f"{coeficiente} {elemento}" for elemento, coeficiente in balanceo[1].items()])
print(f"{reactante_equilibrado} -> {producto_equilibrado}")

# %% [markdown]
# Pregunta 4: Notación científica (4 puntos)
# Imprime las siguientes operaciones según la notación científica:
#
# (1) 1.321×10−4+8.5×10−2
#
# (2) 1.71×103−2.01×102
# (3) (7.4×105)(7.2×104)
#
# (4) (7.4×105)/(7.2×104)

# %%
a = 1.321e-4 + 8.5e-2
b = 1.71e3 - 2.01e2
c = (7.4e5) * (7.2e4)
d = (7.4e5) / (7.2e4)
print(f"respuesta 1: {a}")
print(f"respuesta 2: {b}")
print(f"respuesta 3: {c}")
print(f"respuesta 4: {d}")

# %% [markdown]
# Pregunta 5: Método científico (4 puntos)
# Artículo: https://bit.ly/3surZ1W Leer el siguiente artículo y explica cómo es aplicado el método científico. Emplea como máximo 300 palabras.

# %% [markdown]
# Este artículo gira en torno al material LK-99, la idea era comprobar la teoría de que si este compuesto era un superconductor y para ello realizaron experimentos y analisis teoricos.
#
# Los cientificos lograron demostrar que levitacion y resistividad eran efectos de ferromagnetismo.
#
# Hicieron pruebas con radiografías y  estudios de cristales con el fin de demostrar que el LK-99 no era superconductor y explicaron que los resultados de levitación y resistividad tenían mucho que ver con impurezas específicas en las muestras.
#
# Puedo decir que los cientificos aplicaron el metodo cientifico al observar el compuesto LK-99 e identificar como actuaba; plantearon su hipotesis sobre si era un superconductor; realizaron los experimentos necesarios; analizaron los resultados de los experimentos y finalmente concluyeron que no era un superconductor porque los resultados de levitación y resistividad se debían a impurezas en las muestras.
